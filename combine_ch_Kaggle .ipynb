# %%
pip install pillow numpy matplotlib

# %%
import os
from PIL import Image
from collections import defaultdict
import gc
import re

count = 1  # For counting processed files

# 🔍 Extract patient, trial, condition, channel from filename
def parse_filename(filename):
    match = re.match(r"sub(\d+)_trial(\d+)_cond(\d+\.\d+)_ch(\d+)\.png", filename)
    if match:
        patient = f"sub{match.group(1)}"
        trial = int(match.group(2))
        condition = float(match.group(3))
        channel = int(match.group(4))
        return patient, trial, condition, channel
    return None

# 🧩 Combine 1x19 colored images
def combine_1x19_and_resize(image_paths, image_size=(224, 224), output_size=(224, 224)):
    block_w, block_h = image_size
    canvas = Image.new('RGB', (block_w * 19, block_h), (0, 0, 0))
    black = Image.new('RGB', image_size, (0, 0, 0))

    for idx in range(19):
        if image_paths[idx] is not None:
            img = Image.open(image_paths[idx]).resize(image_size)
        else:
            img = black.copy()
        x = idx * block_w
        canvas.paste(img, (x, 0))
        img.close()

    resized = canvas.resize(output_size)
    return resized

# 🚀 Main processing function
def generate_combined_images(image_dir, output_dir, image_size=(224, 224), output_size=(224, 224)):
    os.makedirs(output_dir, exist_ok=True)
    file_map = defaultdict(lambda: [None]*19)
    global count

    for fname in os.listdir(image_dir):
        if fname.endswith('.png'):
            parsed = parse_filename(fname)
            if parsed:
                patient, trial, condition, channel = parsed
                if 0 <= channel <= 18:
                    key = (patient, trial, condition)
                    file_map[key][channel] = os.path.join(image_dir, fname)

    print(f"🧠 Found {len(file_map)} combinations to process.")

    for (patient, trial, condition), paths in file_map.items():
        out_fname = f"{patient}_trial{trial}_cond{condition}_1x19.png"
        out_path = os.path.join(output_dir, out_fname)
        if os.path.exists(out_path):
            continue  # Skip if already processed

        try:
            combined_img = combine_1x19_and_resize(paths, image_size=image_size, output_size=output_size)
            combined_img.save(out_path)
            combined_img.close()
            del combined_img
            gc.collect()

            print(f"✅ {count}. Saved {out_fname}")
            count += 1

        except Exception as e:
            print(f"❌ Error processing {patient}_trial{trial}_cond{condition}: {e}")
            continue

    print("🎉 Done combining all image sets.")

# 🔧 Example usage
if __name__ == "__main__":
    image_dir = "/home/zeek/External/Top20/schizophrenic"
    output_dir = "/home/zeek/External/Top20_combined/schizophrenic"
    generate_combined_images(image_dir, output_dir)
# Out:
# 🧠 Found 2817 combinations to process.
# ✅ 1. Saved sub25_trial10_cond1.0_1x19.png
# ✅ 2. Saved sub25_trial10_cond2.0_1x19.png
# ✅ 3. Saved sub25_trial10_cond3.0_1x19.png
# ✅ 4. Saved sub25_trial11_cond1.0_1x19.png
# ✅ 5. Saved sub25_trial11_cond2.0_1x19.png
# ✅ 6. Saved sub25_trial11_cond3.0_1x19.png
# ✅ 7. Saved sub25_trial12_cond1.0_1x19.png
# ✅ 8. Saved sub25_trial12_cond2.0_1x19.png
# ✅ 9. Saved sub25_trial12_cond3.0_1x19.png
# ✅ 10. Saved sub25_trial13_cond1.0_1x19.png
# ✅ 11. Saved sub25_trial13_cond2.0_1x19.png
# ✅ 12. Saved sub25_trial13_cond3.0_1x19.png
# ✅ 13. Saved sub75_trial9_cond1.0_1x19.png
# ✅ 14. Saved sub75_trial9_cond2.0_1x19.png
# ✅ 15. Saved sub76_trial1_cond2.0_1x19.png
# ✅ 16. Saved sub76_trial10_cond2.0_1x19.png
# ✅ 17. Saved sub76_trial10_cond3.0_1x19.png
# ✅ 18. Saved sub76_trial11_cond1.0_1x19.png
# ✅ 19. Saved sub76_trial11_cond2.0_1x19.png
# ✅ 20. Saved sub76_trial11_cond3.0_1x19.png
# ✅ 21. Saved sub76_trial12_cond1.0_1x19.png
# ✅ 22. Saved sub76_trial12_cond2.0_1x19.png
# ✅ 23. Saved sub76_trial12_cond3.0_1x19.png
# ✅ 24. Saved sub76_trial13_cond1.0_1x19.png
# ✅ 25. Saved sub76_trial13_cond2.0_1x19.png
# ✅ 26. Saved sub76_trial13_cond3.0_1x19.png
# ✅ 27. Saved sub76_trial14_cond1.0_1x19.png
# ✅ 28. Saved sub76_trial14_cond2.0_1x19.png
# ✅ 29. Saved sub76_trial14_cond3.0_1x19.png
# ✅ 30. Saved sub76_trial15_cond1.0_1x19.png
# ✅ 31. Saved sub76_trial15_cond2.0_1x19.png
# ✅ 32. Saved sub76_trial15_cond3.0_1x19.png
# ✅ 33. Saved sub76_trial16_cond1.0_1x19.png
# ✅ 34. Saved sub76_trial16_cond2.0_1x19.png
# ✅ 35. Saved sub76_trial16_cond3.0_1x19.png
# ✅ 36. Saved sub76_trial17_cond1.0_1x19.png
# ✅ 37. Saved sub76_trial17_cond2.0_1x19.png
# ✅ 38. Saved sub76_trial17_cond3.0_1x19.png
# ✅ 39. Saved sub76_trial18_cond1.0_1x19.png
# ✅ 40. Saved sub76_trial18_cond2.0_1x19.png
# ✅ 41. Saved sub76_trial18_cond3.0_1x19.png
# ✅ 42. Saved sub76_trial19_cond1.0_1x19.png
# ✅ 43. Saved sub76_trial19_cond2.0_1x19.png
# ✅ 44. Saved sub76_trial19_cond3.0_1x19.png
# ✅ 45. Saved sub76_trial1_cond1.0_1x19.png
# ✅ 46. Saved sub76_trial1_cond3.0_1x19.png
# ✅ 47. Saved sub76_trial20_cond1.0_1x19.png
# ✅ 48. Saved sub76_trial20_cond2.0_1x19.png
# ✅ 49. Saved sub76_trial2_cond2.0_1x19.png
# ✅ 50. Saved sub76_trial20_cond3.0_1x19.png
# ✅ 51. Saved sub44_trial7_cond1.0_1x19.png
# ✅ 52. Saved sub44_trial7_cond2.0_1x19.png
# ✅ 53. Saved sub44_trial7_cond3.0_1x19.png
# ✅ 54. Saved sub44_trial8_cond3.0_1x19.png
# ✅ 55. Saved sub44_trial9_cond1.0_1x19.png
# ✅ 56. Saved sub44_trial8_cond2.0_1x19.png
# ✅ 57. Saved sub25_trial19_cond2.0_1x19.png
# ✅ 58. Saved sub25_trial19_cond3.0_1x19.png
# ✅ 59. Saved sub25_trial1_cond1.0_1x19.png
# ✅ 60. Saved sub27_trial5_cond2.0_1x19.png
# ✅ 61. Saved sub27_trial2_cond1.0_1x19.png
# ✅ 62. Saved sub27_trial2_cond2.0_1x19.png
# ✅ 63. Saved sub27_trial2_cond3.0_1x19.png
# ✅ 64. Saved sub74_trial18_cond3.0_1x19.png
# ✅ 65. Saved sub74_trial19_cond1.0_1x19.png
# ✅ 66. Saved sub44_trial8_cond1.0_1x19.png
# ✅ 67. Saved sub44_trial9_cond2.0_1x19.png
# ✅ 68. Saved sub44_trial9_cond3.0_1x19.png
# ✅ 69. Saved sub45_trial10_cond1.0_1x19.png
# ✅ 70. Saved sub45_trial10_cond2.0_1x19.png
# ✅ 71. Saved sub45_trial10_cond3.0_1x19.png
# ✅ 72. Saved sub45_trial11_cond1.0_1x19.png
# ✅ 73. Saved sub45_trial11_cond2.0_1x19.png
# ✅ 74. Saved sub25_trial4_cond1.0_1x19.png
# ✅ 75. Saved sub25_trial9_cond2.0_1x19.png
# ✅ 76. Saved sub26_trial13_cond2.0_1x19.png
# ✅ 77. Saved sub26_trial1_cond3.0_1x19.png
# ✅ 78. Saved sub26_trial6_cond2.0_1x19.png
# ✅ 79. Saved sub27_trial10_cond1.0_1x19.png
# ✅ 80. Saved sub27_trial13_cond2.0_1x19.png
# ✅ 81. Saved sub27_trial17_cond1.0_1x19.png
# ✅ 82. Saved sub27_trial8_cond3.0_1x19.png
# ✅ 83. Saved sub28_trial12_cond2.0_1x19.png
# ✅ 84. Saved sub28_trial16_cond1.0_1x19.png
# ✅ 85. Saved sub28_trial1_cond1.0_1x19.png
# ✅ 86. Saved sub28_trial6_cond2.0_1x19.png
# ✅ 87. Saved sub29_trial10_cond3.0_1x19.png
# ✅ 88. Saved sub74_trial19_cond2.0_1x19.png
# ✅ 89. Saved sub74_trial19_cond3.0_1x19.png
# ✅ 90. Saved sub74_trial1_cond1.0_1x19.png
# ✅ 91. Saved sub74_trial1_cond2.0_1x19.png
# ✅ 92. Saved sub74_trial2_cond3.0_1x19.png
# ✅ 93. Saved sub74_trial2_cond2.0_1x19.png
# ✅ 94. Saved sub74_trial20_cond2.0_1x19.png
# ✅ 95. Saved sub74_trial20_cond3.0_1x19.png
# ✅ 96. Saved sub74_trial2_cond1.0_1x19.png
# ✅ 97. Saved sub74_trial3_cond1.0_1x19.png
# ✅ 98. Saved sub74_trial3_cond2.0_1x19.png
# ✅ 99. Saved sub74_trial3_cond3.0_1x19.png
# ✅ 100. Saved sub74_trial4_cond1.0_1x19.png
# ✅ 101. Saved sub74_trial4_cond2.0_1x19.png
# ✅ 102. Saved sub74_trial4_cond3.0_1x19.png
# ✅ 103. Saved sub74_trial5_cond1.0_1x19.png
# ✅ 104. Saved sub74_trial5_cond2.0_1x19.png
# ✅ 105. Saved sub74_trial5_cond3.0_1x19.png
# ✅ 106. Saved sub74_trial6_cond1.0_1x19.png
# ✅ 107. Saved sub74_trial6_cond2.0_1x19.png
# ✅ 108. Saved sub74_trial6_cond3.0_1x19.png
# ✅ 109. Saved sub74_trial7_cond2.0_1x19.png
# ✅ 110. Saved sub74_trial7_cond3.0_1x19.png
# ✅ 111. Saved sub74_trial8_cond3.0_1x19.png
# ✅ 112. Saved sub74_trial9_cond1.0_1x19.png
# ✅ 113. Saved sub74_trial9_cond2.0_1x19.png
# ✅ 114. Saved sub74_trial9_cond3.0_1x19.png
# ✅ 115. Saved sub75_trial10_cond1.0_1x19.png
# ✅ 116. Saved sub75_trial10_cond2.0_1x19.png
# ✅ 117. Saved sub75_trial10_cond3.0_1x19.png
# ✅ 118. Saved sub75_trial1_cond3.0_1x19.png
# ✅ 119. Saved sub75_trial20_cond1.0_1x19.png
# ✅ 120. Saved sub75_trial11_cond1.0_1x19.png
# ✅ 121. Saved sub75_trial11_cond2.0_1x19.png
# ✅ 122. Saved sub75_trial11_cond3.0_1x19.png
# ✅ 123. Saved sub75_trial12_cond1.0_1x19.png
# ✅ 124. Saved sub75_trial12_cond2.0_1x19.png
# ✅ 125. Saved sub75_trial12_cond3.0_1x19.png
# ✅ 126. Saved sub75_trial13_cond1.0_1x19.png
# ✅ 127. Saved sub75_trial13_cond2.0_1x19.png
# ✅ 128. Saved sub75_trial13_cond3.0_1x19.png
# ✅ 129. Saved sub75_trial14_cond1.0_1x19.png
# ✅ 130. Saved sub75_trial14_cond2.0_1x19.png
# ✅ 131. Saved sub75_trial14_cond3.0_1x19.png
# ✅ 132. Saved sub75_trial20_cond2.0_1x19.png
# ✅ 133. Saved sub75_trial15_cond1.0_1x19.png
# ✅ 134. Saved sub75_trial15_cond2.0_1x19.png
# ✅ 135. Saved sub75_trial20_cond3.0_1x19.png
# ✅ 136. Saved sub75_trial2_cond1.0_1x19.png
# ✅ 137. Saved sub75_trial2_cond2.0_1x19.png
# ✅ 138. Saved sub75_trial2_cond3.0_1x19.png
# ✅ 139. Saved sub75_trial3_cond1.0_1x19.png
# ✅ 140. Saved sub75_trial3_cond2.0_1x19.png
# ✅ 141. Saved sub75_trial3_cond3.0_1x19.png
# ✅ 142. Saved sub75_trial4_cond1.0_1x19.png
# ✅ 143. Saved sub75_trial4_cond2.0_1x19.png
# ✅ 144. Saved sub75_trial15_cond3.0_1x19.png
# ✅ 145. Saved sub75_trial16_cond1.0_1x19.png
# ✅ 146. Saved sub75_trial16_cond2.0_1x19.png
# ✅ 147. Saved sub75_trial16_cond3.0_1x19.png
# ✅ 148. Saved sub75_trial17_cond1.0_1x19.png
# ✅ 149. Saved sub75_trial17_cond2.0_1x19.png
# ✅ 150. Saved sub76_trial2_cond3.0_1x19.png
# ✅ 151. Saved sub76_trial3_cond1.0_1x19.png
# ✅ 152. Saved sub77_trial7_cond1.0_1x19.png
# ✅ 153. Saved sub77_trial7_cond3.0_1x19.png
# ✅ 154. Saved sub77_trial8_cond2.0_1x19.png
# ✅ 155. Saved sub77_trial8_cond1.0_1x19.png
# ✅ 156. Saved sub27_trial7_cond1.0_1x19.png
# ✅ 157. Saved sub27_trial7_cond2.0_1x19.png
# ✅ 158. Saved sub40_trial6_cond1.0_1x19.png
# ✅ 159. Saved sub40_trial6_cond3.0_1x19.png
# ✅ 160. Saved sub43_trial1_cond2.0_1x19.png
# ✅ 161. Saved sub43_trial20_cond1.0_1x19.png
# ✅ 162. Saved sub43_trial10_cond2.0_1x19.png
# ✅ 163. Saved sub43_trial10_cond3.0_1x19.png
# ✅ 164. Saved sub43_trial11_cond1.0_1x19.png
# ✅ 165. Saved sub43_trial11_cond2.0_1x19.png
# ✅ 166. Saved sub43_trial11_cond3.0_1x19.png
# ✅ 167. Saved sub43_trial12_cond1.0_1x19.png
# ✅ 168. Saved sub43_trial12_cond2.0_1x19.png
# ✅ 169. Saved sub43_trial12_cond3.0_1x19.png
# ✅ 170. Saved sub40_trial7_cond1.0_1x19.png
# ✅ 171. Saved sub40_trial7_cond3.0_1x19.png
# ✅ 172. Saved sub40_trial8_cond1.0_1x19.png
# ✅ 173. Saved sub40_trial8_cond2.0_1x19.png
# ✅ 174. Saved sub40_trial9_cond1.0_1x19.png
# ✅ 175. Saved sub40_trial9_cond2.0_1x19.png
# ✅ 176. Saved sub40_trial9_cond3.0_1x19.png
# ✅ 177. Saved sub41_trial10_cond3.0_1x19.png
# ✅ 178. Saved sub41_trial11_cond1.0_1x19.png
# ✅ 179. Saved sub41_trial11_cond2.0_1x19.png
# ✅ 180. Saved sub41_trial12_cond1.0_1x19.png
# ✅ 181. Saved sub41_trial12_cond3.0_1x19.png
# ✅ 182. Saved sub43_trial13_cond1.0_1x19.png
# ✅ 183. Saved sub43_trial13_cond2.0_1x19.png
# ✅ 184. Saved sub43_trial13_cond3.0_1x19.png
# ✅ 185. Saved sub43_trial14_cond1.0_1x19.png
# ✅ 186. Saved sub43_trial14_cond3.0_1x19.png
# ✅ 187. Saved sub43_trial15_cond1.0_1x19.png
# ✅ 188. Saved sub43_trial15_cond2.0_1x19.png
# ✅ 189. Saved sub43_trial15_cond3.0_1x19.png
# ✅ 190. Saved sub43_trial16_cond1.0_1x19.png
# ✅ 191. Saved sub43_trial16_cond2.0_1x19.png
# ✅ 192. Saved sub43_trial16_cond3.0_1x19.png
# ✅ 193. Saved sub43_trial17_cond1.0_1x19.png
# ✅ 194. Saved sub43_trial17_cond2.0_1x19.png
# ✅ 195. Saved sub43_trial17_cond3.0_1x19.png
# ✅ 196. Saved sub43_trial18_cond1.0_1x19.png
# ✅ 197. Saved sub43_trial18_cond3.0_1x19.png
# ✅ 198. Saved sub43_trial19_cond1.0_1x19.png
# ✅ 199. Saved sub43_trial19_cond2.0_1x19.png
# ✅ 200. Saved sub43_trial19_cond3.0_1x19.png
# ✅ 201. Saved sub43_trial1_cond1.0_1x19.png
# ✅ 202. Saved sub43_trial20_cond2.0_1x19.png
# ✅ 203. Saved sub43_trial2_cond1.0_1x19.png
# ✅ 204. Saved sub43_trial2_cond2.0_1x19.png
# ✅ 205. Saved sub43_trial2_cond3.0_1x19.png
# ✅ 206. Saved sub43_trial20_cond3.0_1x19.png
# ✅ 207. Saved sub32_trial2_cond1.0_1x19.png
# ✅ 208. Saved sub32_trial2_cond2.0_1x19.png
# ✅ 209. Saved sub33_trial10_cond1.0_1x19.png
# ✅ 210. Saved sub33_trial10_cond2.0_1x19.png
# ✅ 211. Saved sub33_trial5_cond1.0_1x19.png
# ✅ 212. Saved sub33_trial12_cond2.0_1x19.png
# ✅ 213. Saved sub74_trial18_cond2.0_1x19.png
# ✅ 214. Saved sub57_trial3_cond1.0_1x19.png
# ✅ 215. Saved sub57_trial3_cond2.0_1x19.png
# ✅ 216. Saved sub57_trial4_cond2.0_1x19.png
# ✅ 217. Saved sub57_trial4_cond3.0_1x19.png
# ✅ 218. Saved sub31_trial5_cond1.0_1x19.png
# ✅ 219. Saved sub31_trial5_cond2.0_1x19.png
# ✅ 220. Saved sub31_trial6_cond1.0_1x19.png
# ✅ 221. Saved sub31_trial6_cond2.0_1x19.png
# ✅ 222. Saved sub40_trial2_cond1.0_1x19.png
# ✅ 223. Saved sub40_trial2_cond2.0_1x19.png
# ✅ 224. Saved sub43_trial3_cond1.0_1x19.png
# ✅ 225. Saved sub45_trial9_cond2.0_1x19.png
# ✅ 226. Saved sub48_trial13_cond3.0_1x19.png
# ✅ 227. Saved sub48_trial14_cond1.0_1x19.png
# ✅ 228. Saved sub51_trial10_cond1.0_1x19.png
# ✅ 229. Saved sub51_trial1_cond3.0_1x19.png
# ✅ 230. Saved sub51_trial20_cond1.0_1x19.png
# ✅ 231. Saved sub51_trial1_cond2.0_1x19.png
# ✅ 232. Saved sub51_trial10_cond2.0_1x19.png
# ✅ 233. Saved sub51_trial10_cond3.0_1x19.png
# ✅ 234. Saved sub51_trial11_cond1.0_1x19.png
# ✅ 235. Saved sub51_trial11_cond3.0_1x19.png
# ✅ 236. Saved sub57_trial5_cond1.0_1x19.png
# ✅ 237. Saved sub57_trial5_cond2.0_1x19.png
# ✅ 238. Saved sub57_trial5_cond3.0_1x19.png
# ✅ 239. Saved sub57_trial6_cond1.0_1x19.png
# ✅ 240. Saved sub57_trial6_cond2.0_1x19.png
# ✅ 241. Saved sub57_trial6_cond3.0_1x19.png
# ✅ 242. Saved sub57_trial7_cond1.0_1x19.png
# ✅ 243. Saved sub57_trial7_cond2.0_1x19.png
# ✅ 244. Saved sub57_trial7_cond3.0_1x19.png
# ✅ 245. Saved sub57_trial8_cond1.0_1x19.png
# ✅ 246. Saved sub51_trial12_cond1.0_1x19.png
# ✅ 247. Saved sub51_trial12_cond3.0_1x19.png
# ✅ 248. Saved sub51_trial13_cond1.0_1x19.png
# ✅ 249. Saved sub51_trial13_cond2.0_1x19.png
# ✅ 250. Saved sub51_trial13_cond3.0_1x19.png
# ✅ 251. Saved sub51_trial14_cond1.0_1x19.png
# ✅ 252. Saved sub51_trial14_cond3.0_1x19.png
# ✅ 253. Saved sub51_trial15_cond1.0_1x19.png
# ✅ 254. Saved sub51_trial15_cond2.0_1x19.png
# ✅ 255. Saved sub51_trial15_cond3.0_1x19.png
# ✅ 256. Saved sub51_trial16_cond1.0_1x19.png
# ✅ 257. Saved sub51_trial16_cond2.0_1x19.png
# ✅ 258. Saved sub51_trial16_cond3.0_1x19.png
# ✅ 259. Saved sub51_trial17_cond1.0_1x19.png
# ✅ 260. Saved sub51_trial17_cond2.0_1x19.png
# ✅ 261. Saved sub51_trial17_cond3.0_1x19.png
# ✅ 262. Saved sub51_trial18_cond1.0_1x19.png
# ✅ 263. Saved sub51_trial18_cond2.0_1x19.png
# ✅ 264. Saved sub51_trial18_cond3.0_1x19.png
# ✅ 265. Saved sub51_trial19_cond1.0_1x19.png
# ✅ 266. Saved sub51_trial19_cond3.0_1x19.png
# ✅ 267. Saved sub51_trial1_cond1.0_1x19.png
# ✅ 268. Saved sub51_trial19_cond2.0_1x19.png
# ✅ 269. Saved sub27_trial3_cond1.0_1x19.png
# ✅ 270. Saved sub27_trial3_cond2.0_1x19.png
# ✅ 271. Saved sub27_trial4_cond1.0_1x19.png
# ✅ 272. Saved sub27_trial4_cond2.0_1x19.png
# ✅ 273. Saved sub27_trial4_cond3.0_1x19.png
# ✅ 274. Saved sub27_trial5_cond1.0_1x19.png
# ✅ 275. Saved sub27_trial5_cond3.0_1x19.png
# ✅ 276. Saved sub27_trial6_cond1.0_1x19.png
# ✅ 277. Saved sub27_trial6_cond2.0_1x19.png
# ✅ 278. Saved sub27_trial6_cond3.0_1x19.png
# ✅ 279. Saved sub27_trial7_cond3.0_1x19.png
# ✅ 280. Saved sub27_trial8_cond1.0_1x19.png
# ✅ 281. Saved sub27_trial8_cond2.0_1x19.png
# ✅ 282. Saved sub25_trial14_cond1.0_1x19.png
# ✅ 283. Saved sub25_trial14_cond2.0_1x19.png
# ✅ 284. Saved sub25_trial15_cond3.0_1x19.png
# ✅ 285. Saved sub25_trial14_cond3.0_1x19.png
# ✅ 286. Saved sub25_trial16_cond1.0_1x19.png
# ✅ 287. Saved sub25_trial15_cond1.0_1x19.png
# ✅ 288. Saved sub25_trial15_cond2.0_1x19.png
# ✅ 289. Saved sub25_trial17_cond1.0_1x19.png
# ✅ 290. Saved sub25_trial16_cond2.0_1x19.png
# ✅ 291. Saved sub25_trial17_cond2.0_1x19.png
# ✅ 292. Saved sub25_trial17_cond3.0_1x19.png
# ✅ 293. Saved sub25_trial18_cond1.0_1x19.png
# ✅ 294. Saved sub25_trial18_cond2.0_1x19.png
# ✅ 295. Saved sub25_trial18_cond3.0_1x19.png
# ✅ 296. Saved sub25_trial19_cond1.0_1x19.png
# ✅ 297. Saved sub25_trial16_cond3.0_1x19.png
# ✅ 298. Saved sub45_trial2_cond1.0_1x19.png
# ✅ 299. Saved sub45_trial7_cond1.0_1x19.png
# ✅ 300. Saved sub45_trial7_cond2.0_1x19.png
# ✅ 301. Saved sub45_trial7_cond3.0_1x19.png
# ✅ 302. Saved sub45_trial8_cond1.0_1x19.png
# ✅ 303. Saved sub45_trial8_cond2.0_1x19.png
# ✅ 304. Saved sub45_trial8_cond3.0_1x19.png
# ✅ 305. Saved sub48_trial13_cond2.0_1x19.png
# ✅ 306. Saved sub45_trial9_cond3.0_1x19.png
# ✅ 307. Saved sub38_trial3_cond1.0_1x19.png
# ✅ 308. Saved sub38_trial3_cond2.0_1x19.png
# ✅ 309. Saved sub38_trial4_cond1.0_1x19.png
# ✅ 310. Saved sub38_trial4_cond2.0_1x19.png
# ✅ 311. Saved sub39_trial19_cond2.0_1x19.png
# ✅ 312. Saved sub39_trial19_cond3.0_1x19.png
# ✅ 313. Saved sub40_trial16_cond1.0_1x19.png
# ✅ 314. Saved sub40_trial16_cond2.0_1x19.png
# ✅ 315. Saved sub40_trial16_cond3.0_1x19.png
# ✅ 316. Saved sub40_trial17_cond1.0_1x19.png
# ✅ 317. Saved sub40_trial17_cond2.0_1x19.png
# ✅ 318. Saved sub38_trial4_cond3.0_1x19.png
# ✅ 319. Saved sub40_trial17_cond3.0_1x19.png
# ✅ 320. Saved sub40_trial18_cond1.0_1x19.png
# ✅ 321. Saved sub40_trial18_cond2.0_1x19.png
# ✅ 322. Saved sub38_trial5_cond1.0_1x19.png
# ✅ 323. Saved sub38_trial5_cond2.0_1x19.png
# ✅ 324. Saved sub38_trial5_cond3.0_1x19.png
# ✅ 325. Saved sub38_trial6_cond1.0_1x19.png
# ✅ 326. Saved sub38_trial6_cond2.0_1x19.png
# ✅ 327. Saved sub38_trial6_cond3.0_1x19.png
# ✅ 328. Saved sub38_trial7_cond1.0_1x19.png
# ✅ 329. Saved sub38_trial7_cond2.0_1x19.png
# ✅ 330. Saved sub38_trial7_cond3.0_1x19.png
# ✅ 331. Saved sub38_trial8_cond1.0_1x19.png
# ✅ 332. Saved sub38_trial8_cond2.0_1x19.png
# ✅ 333. Saved sub38_trial8_cond3.0_1x19.png
# ✅ 334. Saved sub38_trial9_cond1.0_1x19.png
# ✅ 335. Saved sub38_trial9_cond2.0_1x19.png
# ✅ 336. Saved sub40_trial18_cond3.0_1x19.png
# ✅ 337. Saved sub40_trial19_cond1.0_1x19.png
# ✅ 338. Saved sub40_trial19_cond2.0_1x19.png
# ✅ 339. Saved sub40_trial19_cond3.0_1x19.png
# ✅ 340. Saved sub40_trial1_cond1.0_1x19.png
# ✅ 341. Saved sub40_trial1_cond2.0_1x19.png
# ✅ 342. Saved sub40_trial20_cond2.0_1x19.png
# ✅ 343. Saved sub40_trial20_cond3.0_1x19.png
# ✅ 344. Saved sub33_trial8_cond1.0_1x19.png
# ✅ 345. Saved sub33_trial8_cond2.0_1x19.png
# ✅ 346. Saved sub33_trial8_cond3.0_1x19.png
# ✅ 347. Saved sub33_trial9_cond1.0_1x19.png
# ✅ 348. Saved sub33_trial9_cond2.0_1x19.png
# ✅ 349. Saved sub34_trial10_cond3.0_1x19.png
# ✅ 350. Saved sub34_trial11_cond1.0_1x19.png
# ✅ 351. Saved sub35_trial3_cond1.0_1x19.png
# ✅ 352. Saved sub35_trial3_cond2.0_1x19.png
# ✅ 353. Saved sub35_trial3_cond3.0_1x19.png
# ✅ 354. Saved sub37_trial4_cond1.0_1x19.png
# ✅ 355. Saved sub37_trial5_cond1.0_1x19.png
# ✅ 356. Saved sub37_trial5_cond2.0_1x19.png
# ✅ 357. Saved sub37_trial5_cond3.0_1x19.png
# ✅ 358. Saved sub37_trial7_cond1.0_1x19.png
# ✅ 359. Saved sub37_trial7_cond2.0_1x19.png
# ✅ 360. Saved sub27_trial1_cond2.0_1x19.png
# ✅ 361. Saved sub27_trial1_cond3.0_1x19.png
# ✅ 362. Saved sub25_trial20_cond1.0_1x19.png
# ✅ 363. Saved sub25_trial20_cond2.0_1x19.png
# ✅ 364. Saved sub27_trial1_cond1.0_1x19.png
# ✅ 365. Saved sub27_trial10_cond2.0_1x19.png
# ✅ 366. Saved sub27_trial10_cond3.0_1x19.png
# ✅ 367. Saved sub27_trial11_cond1.0_1x19.png
# ✅ 368. Saved sub27_trial11_cond2.0_1x19.png
# ✅ 369. Saved sub27_trial11_cond3.0_1x19.png
# ✅ 370. Saved sub27_trial12_cond1.0_1x19.png
# ✅ 371. Saved sub27_trial12_cond2.0_1x19.png
# ✅ 372. Saved sub25_trial1_cond3.0_1x19.png
# ✅ 373. Saved sub25_trial20_cond3.0_1x19.png
# ✅ 374. Saved sub25_trial2_cond1.0_1x19.png
# ✅ 375. Saved sub25_trial2_cond2.0_1x19.png
# ✅ 376. Saved sub25_trial2_cond3.0_1x19.png
# ✅ 377. Saved sub25_trial3_cond1.0_1x19.png
# ✅ 378. Saved sub25_trial3_cond2.0_1x19.png
# ✅ 379. Saved sub25_trial3_cond3.0_1x19.png
# ✅ 380. Saved sub27_trial13_cond3.0_1x19.png
# ✅ 381. Saved sub27_trial12_cond3.0_1x19.png
# ✅ 382. Saved sub27_trial13_cond1.0_1x19.png
# ✅ 383. Saved sub27_trial14_cond1.0_1x19.png
# ✅ 384. Saved sub27_trial14_cond2.0_1x19.png
# ✅ 385. Saved sub27_trial14_cond3.0_1x19.png
# ✅ 386. Saved sub27_trial15_cond1.0_1x19.png
# ✅ 387. Saved sub27_trial15_cond2.0_1x19.png
# ✅ 388. Saved sub27_trial15_cond3.0_1x19.png
# ✅ 389. Saved sub27_trial16_cond1.0_1x19.png
# ✅ 390. Saved sub27_trial16_cond2.0_1x19.png
# ✅ 391. Saved sub27_trial16_cond3.0_1x19.png
# ✅ 392. Saved sub27_trial17_cond2.0_1x19.png
# ✅ 393. Saved sub27_trial17_cond3.0_1x19.png
# ✅ 394. Saved sub27_trial18_cond1.0_1x19.png
# ✅ 395. Saved sub27_trial18_cond2.0_1x19.png
# ✅ 396. Saved sub27_trial18_cond3.0_1x19.png
# ✅ 397. Saved sub27_trial19_cond1.0_1x19.png
# ✅ 398. Saved sub27_trial19_cond2.0_1x19.png
# ✅ 399. Saved sub27_trial19_cond3.0_1x19.png
# ✅ 400. Saved sub27_trial20_cond1.0_1x19.png
# ✅ 401. Saved sub27_trial20_cond2.0_1x19.png
# ✅ 402. Saved sub27_trial20_cond3.0_1x19.png
# ✅ 403. Saved sub43_trial9_cond1.0_1x19.png
# ✅ 404. Saved sub44_trial1_cond1.0_1x19.png
# ✅ 405. Saved sub44_trial1_cond2.0_1x19.png
# ✅ 406. Saved sub44_trial10_cond1.0_1x19.png
# ✅ 407. Saved sub44_trial10_cond2.0_1x19.png
# ✅ 408. Saved sub44_trial10_cond3.0_1x19.png
# ✅ 409. Saved sub44_trial11_cond1.0_1x19.png
# ✅ 410. Saved sub44_trial1_cond3.0_1x19.png
# ✅ 411. Saved sub44_trial11_cond2.0_1x19.png
# ✅ 412. Saved sub44_trial11_cond3.0_1x19.png
# ✅ 413. Saved sub43_trial3_cond2.0_1x19.png
# ✅ 414. Saved sub43_trial3_cond3.0_1x19.png
# ✅ 415. Saved sub43_trial4_cond1.0_1x19.png
# ✅ 416. Saved sub43_trial4_cond2.0_1x19.png
# ✅ 417. Saved sub43_trial4_cond3.0_1x19.png
# ✅ 418. Saved sub43_trial5_cond1.0_1x19.png
# ✅ 419. Saved sub43_trial5_cond2.0_1x19.png
# ✅ 420. Saved sub43_trial6_cond1.0_1x19.png
# ✅ 421. Saved sub43_trial6_cond2.0_1x19.png
# ✅ 422. Saved sub43_trial6_cond3.0_1x19.png
# ✅ 423. Saved sub43_trial7_cond1.0_1x19.png
# ✅ 424. Saved sub43_trial7_cond2.0_1x19.png
# ✅ 425. Saved sub43_trial8_cond1.0_1x19.png
# ✅ 426. Saved sub43_trial8_cond2.0_1x19.png
# ✅ 427. Saved sub43_trial8_cond3.0_1x19.png
# ✅ 428. Saved sub44_trial12_cond1.0_1x19.png
# ✅ 429. Saved sub44_trial12_cond2.0_1x19.png
# ✅ 430. Saved sub44_trial12_cond3.0_1x19.png
# ✅ 431. Saved sub44_trial13_cond1.0_1x19.png
# ✅ 432. Saved sub44_trial13_cond2.0_1x19.png
# ✅ 433. Saved sub44_trial13_cond3.0_1x19.png
# ✅ 434. Saved sub44_trial14_cond1.0_1x19.png
# ✅ 435. Saved sub44_trial14_cond2.0_1x19.png
# ✅ 436. Saved sub44_trial14_cond3.0_1x19.png
# ✅ 437. Saved sub44_trial15_cond1.0_1x19.png
# ✅ 438. Saved sub44_trial15_cond2.0_1x19.png

# %%
# !pip install opencv-python
