# %%
# prompt: mount drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mne
# !pip install ssqueezepy
# !pip install stockwell
# !pip install tensorflow
# !pip install kaggle
# Out:
# Requirement already satisfied: mne in /home/zeek/anaconda3/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: decorator in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (5.1.1)
# Requirement already satisfied: jinja2 in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (3.1.4)
# Requirement already satisfied: lazy-loader>=0.3 in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (3.9.2)
# Requirement already satisfied: numpy<3,>=1.23 in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (1.26.4)
# Requirement already satisfied: packaging in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (24.1)
# Requirement already satisfied: pooch>=1.5 in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (1.13.1)
# Requirement already satisfied: tqdm in /home/zeek/anaconda3/lib/python3.12/site-packages (from mne) (4.66.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->mne) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/zeek/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->mne) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->mne) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->mne) (1.4.4)
# Requirement already satisfied: pillow>=8 in /home/zeek/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->mne) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->mne) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeek/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.6->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from pooch>=1.5->mne) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: six>=1.5 in /home/zeek/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zeek/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeek/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeek/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.8.30)
# Requirement already satisfied: ssqueezepy in /home/zeek/anaconda3/lib/python3.12/site-packages (0.6.5)
# Requirement already satisfied: numpy in /home/zeek/anaconda3/lib/python3.12/site-packages (from ssqueezepy) (1.26.4)
# Requirement already satisfied: numba in /home/zeek/anaconda3/lib/python3.12/site-packages (from ssqueezepy) (0.60.0)
# Requirement already satisfied: scipy in /home/zeek/anaconda3/lib/python3.12/site-packages (from ssqueezepy) (1.13.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from numba->ssqueezepy) (0.43.0)
# Requirement already satisfied: tensorflow in /home/zeek/anaconda3/lib/python3.12/site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /home/zeek/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /home/zeek/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /home/zeek/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zeek/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeek/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeek/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeek/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /home/zeek/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %%
import matplotlib.pyplot as plt
import os
os.environ['SSQ_GPU'] = '1'
from ssqueezepy import ssq_cwt
import numpy as np
# from stockwell import st
from sklearn.preprocessing import MinMaxScaler
import mne
from scipy.ndimage import zoom
import tensorflow as tf

# %% [markdown]
# import demographic.csv

# %%
import pandas as pd
demo = pd.read_csv('/home/zeek/Downloads/demographic.csv')
demo
# demographic.csv determined the class of the .csv files in the dataset
# Out:
#     subject   group  gender   age   education
# 0         1       0       M    44        16.0
# 1         2       0       M    39        17.0
# 2         3       0       M    53        18.0
# 3         4       0       M    52        15.0
# 4         5       0       M    41        16.0
# ..      ...     ...     ...   ...         ...
# 76       77       1       M    28        13.0
# 77       78       1       F    32        16.0
# 78       79       1       M    37        16.0
# 79       80       1       M    33        13.0
# 80       81       1       M    56        13.0
#
# [81 rows x 5 columns]

# %% [markdown]
# Code to save already processed files

# %%
import os
import numpy as np
import pandas as pd
import re
import gc
import psutil
from PIL import Image
import mne
from ssqueezepy import ssq_cwt

count = 1
# Define directories
directory = '/home/zeek/External/Divide-20250317T133000Z-001/Divide/'
output_directory = "/home/zeek/External/Images/I660es_1/"
processed_file_path = "/home/zeek/Downloads/processed_files_part_5.txt"

# Load the list of processed files
if os.path.exists(processed_file_path):
    with open(processed_file_path, "r", encoding="utf-8") as f:
        processed_files = set(f.read().splitlines())
else:
    processed_files = set()

# List all relevant CSV files
csv_files = [f for f in os.listdir(directory) if f.startswith('downsampled_') and f.endswith('.csv')]

def memory_usage():
    """Prints memory usage in MB."""
    process = psutil.Process(os.getpid())
    print(f"Memory Usage: {process.memory_info().rss / (1024 * 1024):.2f} MB")

def save_tfr_image(tfr_data, category, filename, output_directory):
    os.makedirs(os.path.join(output_directory, category), exist_ok=True)

    # Normalize TFR data to [0, 255]
    tfr_data_normalized = (tfr_data - np.min(tfr_data)) / (np.max(tfr_data) - np.min(tfr_data)) * 255
    img = Image.fromarray(tfr_data_normalized.astype(np.uint8))
    img = img.resize((224, 224), Image.LANCZOS)
    img.save(os.path.join(output_directory, category, f"{filename}.png"))

    # Cleanup
    del img, tfr_data_normalized
    gc.collect()

def generate_tfrs(csv_file):
    global count

    # Skip already processed files
    if csv_file in processed_files:
        print(f"Skipping already processed file: {csv_file}")
        return

    print(f"Processing file: {csv_file}")
    print(f"Count: {count}/1660")
    count += 1

    # Extract patient and trial numbers from filename
    match = re.search(r"downsampled_(\d+)_part_(\d+)\.csv", csv_file)
    if match:
        patient_num = int(match.group(1))
        trial_num = int(match.group(2))
    else:
        print(f"Skipping file {csv_file} due to incorrect format.")
        return

    file_path = os.path.join(directory, csv_file)

    try:
        df = pd.read_csv(file_path)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}, skipping.")
        return

    # Ensure 'condition' column exists
    if "condition" not in df.columns:
        print(f"Condition column not found in {csv_file}, skipping file.")
        return

    # Group data by condition
    grouped = df.groupby("condition")

    for condition_num, group in grouped:
        data = group.iloc[:, :-4].values.T.astype(np.float32)  # Transpose to (channels, time)
        print(f"Processing Condition: {condition_num}, Data Shape: {data.shape}")

        channel_names = list(df.columns[:-4])
        info = mne.create_info(ch_names=channel_names, sfreq=128, ch_types='eeg')
        raw = mne.io.RawArray(data, info)
        raw.pick(['Fp1', 'Fp2','F7', 'F3', 'Fz', 'F4', 'F8', 'T7', 'C3', 'Cz', 'C4', 'T8', 'TP7', 'P3', 'Pz', 'P4', 'TP8', 'O1', 'O2'])
        data = raw.get_data()
        print(f"Updated : {data.shape}")

        for k in range(data.shape[0]):  # Iterate over channels
            channel_data = data[k, :]

            # Compute synchrosqueezing transform
            try:
                Twxo, Wxo, *_ = ssq_cwt(channel_data, astensor=True)
                window_tfr = np.abs(Twxo.cpu().data.numpy())
            except Exception as e:
                print(f"Error processing TFR for {csv_file}, channel {k}: {e}")
                continue

            # Generate filename with patient, trial, condition, and channel
            filename = f"sub{patient_num}_trial{trial_num}_cond{condition_num}_ch{k}"
            category = 'schizophrenic' if demo.iloc[patient_num - 1, 1] else 'healthy'

            save_tfr_image(window_tfr, category, filename, output_directory)

            # Clear memory after each channel
            del Twxo, Wxo, window_tfr, channel_data
            gc.collect()

    # Append to processed files list
    with open(processed_file_path, "a") as f:
        f.write(csv_file + "\n")

    processed_files.add(csv_file)

    # Clear memory after each file
    del df
    gc.collect()

# Process each CSV file
for csv_file in csv_files:
    generate_tfrs(csv_file)
    memory_usage()

print(count)
print("Completed")
# Out:
# Processing file: downsampled_10_part_16.csv
# Count: 1/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1404.36 MB
# Processing file: downsampled_10_part_26.csv
# Count: 2/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1408.38 MB
# Processing file: downsampled_10_part_30.csv
# Count: 3/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1408.38 MB
# Processing file: downsampled_10_part_34.csv
# Count: 4/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1408.62 MB
# Processing file: downsampled_10_part_35.csv
# Count: 5/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1408.62 MB
# Processing file: downsampled_10_part_36.csv
# Count: 6/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1409.00 MB
# Processing file: downsampled_10_part_38.csv
# Count: 7/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1409.00 MB
# Processing file: downsampled_10_part_39.csv
# Count: 8/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1409.00 MB
# Processing file: downsampled_10_part_40.csv
# Count: 9/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1409.00 MB
# Processing file: downsampled_10_part_41.csv
# Count: 10/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 
1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1410.62 MB
# Processing file: downsampled_44_part_75.csv
# Count: 58/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1410.62 MB
# Processing file: downsampled_44_part_76.csv
# Count: 59/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1411.98 MB
# Processing file: downsampled_44_part_77.csv
# Count: 60/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1411.73 MB
# Processing file: downsampled_44_part_78.csv
# Count: 61/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1411.73 MB
# Processing file: downsampled_44_part_79.csv
# Count: 62/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1409.61 MB
# Processing file: downsampled_44_part_8.csv
# Count: 63/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1409.61 MB
# Processing file: downsampled_44_part_80.csv
# Count: 64/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1409.11 MB
# Processing file: downsampled_44_part_81.csv
# Count: 65/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1409.11 MB
# Processing file: downsampled_44_part_82.csv
# Count: 66/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_44_part_83.csv
# Count: 67/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_44_part_84.csv
# Count: 68/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_44_part_85.csv
# Count: 69/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_44_part_86.csv
# Count: 70/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_10_part_58.csv
# Count: 71/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_10_part_74.csv
# Count: 72/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_10_part_89.csv
# Count: 73/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_13_part_77.csv
# Count: 74/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1406.23 MB
# Processing file: downsampled_15_part_44.csv
# Count: 75/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# ...
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_65.csv
# Count: 1638/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_66.csv
# Count: 1639/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_67.csv
# Count: 1640/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_68.csv
# Count: 1641/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_69.csv
# Count: 1642/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_70.csv
# Count: 1643/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_71.csv
# Count: 1644/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_72.csv
# Count: 1645/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_10_part_73.csv
# Count: 1646/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_20.csv
# Count: 1647/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_21.csv
# Count: 1648/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_22.csv
# Count: 1649/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_23.csv
# Count: 1650/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_24.csv
# Count: 1651/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_25.csv
# Count: 1652/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_26.csv
# Count: 1653/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_27.csv
# Count: 1654/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_28.csv
# Count: 1655/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_29.csv
# Count: 1656/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_30.csv
# Count: 1657/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_31.csv
# Count: 1658/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_32.csv
# Count: 1659/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# Processing file: downsampled_25_part_33.csv
# Count: 1660/1660
# Processing Condition: 1.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 2.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Processing Condition: 3.0, Data Shape: (70, 384)
# Creating RawArray with float64 data, n_channels=70, n_times=384
#     Range : 0 ... 383 =      0.000 ...     2.992 secs
# Ready.
# Updated : (19, 384)
# Memory Usage: 1175.00 MB
# 1661
# Completed
